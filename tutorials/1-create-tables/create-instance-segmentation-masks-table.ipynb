# %% [markdown]
# # Create Table from instance segmentation masks
#
# <!-- Tags: ["Instance Segmentation", "COCO", "Write Table", "Masks"] -->
#
# This notebook demonstrates how to create a table of instance segmentation masks.
#
# ![img](../images/instance-segmentation.jpg)
#
# "Instance segmentation", as opposed to "semantic segmentation", refers to situations where each "object" in your dataset has some associated segmentation mask which might overlap with other objects. "Semantic segmentation", by contrast, refers to situations where each pixel in each image of your dataset is associated with exactly one class label. See [this notebook](https://github.com/3lc-ai/3lc-examples/blob/main/tutorials/1-create-tables/create-semantic-segmentation-dataset.ipynb) for an example of how to create a table from semantic segmentation masks.
#
# This notebook will use instance segmentations represented as a 3D tensor of shape `(width, height, num_instances)`. For an example of how to use instance segmentations represented as polygons, see [this notebook](https://github.com/3lc-ai/3lc-examples/blob/main/tutorials/1-create-tables/create-instance-segmentation-polygons-table.ipynb).
#
# We will use the COCO128 for this example. Note that while 3LC has built-in functionality to facilitate the loading of COCO-style datasets, this example will more "manually" load the dataset to demonstrate how this can be done in general.

# %% [markdown]
# ## Project Setup

# %%
PROJECT_NAME = "3LC Tutorials"
DATASET_NAME = "COCO128 Segmentation Masks"
DATA_PATH = "../../data"

# %% [markdown]
# ## Install dependencies

# %%
# %pip install 3lc
# %pip install pycocotools
# Out:
# Requirement already satisfied: 3lc in c:\project\notebook-examples\.venv\lib\site-packages (2.20)
# Requirement already satisfied: cachetools<6.0.0,>=5.5.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (5.5.2)
# Requirement already satisfied: cryptlex-lexactivator<4.0.0,>=3.28.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (3.31.3)
# Requirement already satisfied: cryptography>=44.0.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (46.0.3)
# Requirement already satisfied: deepdiff>=8.6.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (8.6.1)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (3.18.0)
# Requirement already satisfied: litestar<2.16.0,>=2.15.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.15.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.1.1)
# Requirement already satisfied: opencv-python>=4.11.0.86 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (4.11.0.86)
# Requirement already satisfied: packaging>=23.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (24.2)
# Requirement already satisfied: pandas>=1.4.2 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.2.3)
# Requirement already satisfied: pillow<11.0.0,>=10.4.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (10.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=3.8.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (3.11.0)
# Requirement already satisfied: psutil<6.0.0,>=5.9.8 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (5.9.8)
# Requirement already satisfied: pyarrow>=18 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (21.0.0)
# Requirement already satisfied: pycocotools<3.0.0,>=2.0.10 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.0.10)
# Requirement already satisfied: pydantic>=2 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.11.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.10.1)
# Requirement already satisfied: pywin32<311,>=310 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (310)
# Requirement already satisfied: randomname<1.0.0,>=0.2.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (0.2.1)
# Requirement already satisfied: readerwriterlock<2.0.0,>=1.0.9 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.4.2 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (13.9.4)
# Requirement already satisfied: ruamel-yaml<1.0.0,>=0.17.32 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (0.18.10)
# Requirement already satisfied: s3fs==2024.3.1 in c:\project\notebook-examples\.venv\lib\site-packages (from s3fs[boto3]==2024.3.1->3lc) (2024.3.1)
# Requirement already satisfied: sentry-sdk<2.15.0,>=2.13.0 in c:\project\notebook-examples\.venv\lib\site-packages (from sentry-sdk[litestar]<2.15.0,>=2.13.0->3lc) (2.14.0)
# Requirement already satisfied: termcolor>=2.2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (3.0.1)
# Requirement already satisfied: textual<1.0.0,>=0.52.1 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (0.89.1)
# Requirement already satisfied: torch>=1.8.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (2.6.0)
# Requirement already satisfied: torchvision>=0.10.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (0.21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (4.67.1)
# Requirement already satisfied: urllib3<2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (1.26.20)
# Requirement already satisfied: uvicorn>=0.17.6 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (0.34.0)
# Requirement already satisfied: watchdog<6.0.0,>=4.0.0 in c:\project\notebook-examples\.venv\lib\site-packages (from 3lc) (5.0.3)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\project\notebook-examples\.venv\lib\site-packages (from s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (2.21.1)
# Requirement already satisfied: fsspec==2024.3.1 in c:\project\notebook-examples\.venv\lib\site-packages (from s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (2024.3.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\project\notebook-examples\.venv\lib\site-packages (from s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (3.11.16)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (0.12.0)
# Requirement already satisfied: botocore<1.37.2,>=1.37.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.37.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (6.3.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.17.2)
# Requirement already satisfied: boto3<1.37.2,>=1.37.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiobotocore[boto3]<3.0.0,>=2.5.4; extra == "boto3"->s3fs[boto3]==2024.3.1->3lc) (1.37.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\project\notebook-examples\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.19.0)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\project\notebook-examples\.venv\lib\site-packages (from boto3<1.37.2,>=1.37.0->aiobotocore[boto3]<3.0.0,>=2.5.4; extra == "boto3"->s3fs[boto3]==2024.3.1->3lc) (0.11.3)
# Requirement already satisfied: anyio>=3 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (4.9.0)
# Requirement already satisfied: click in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (8.1.8)
# Requirement already satisfied: httpx>=0.22 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (0.4.1)
# Requirement already satisfied: msgspec>=0.18.2 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (0.19.0)
# Requirement already satisfied: multipart>=1.2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (1.2.1)
# Requirement already satisfied: polyfactory>=2.6.3 in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (2.20.0)
# Requirement already satisfied: pyyaml in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (6.0.2)
# Requirement already satisfied: rich-click in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (1.8.8)
# Requirement already satisfied: typing-extensions in c:\project\notebook-examples\.venv\lib\site-packages (from litestar<2.16.0,>=2.15.0->3lc) (4.13.1)
# Requirement already satisfied: six>=1.5 in c:\project\notebook-examples\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs==2024.3.1->s3fs[boto3]==2024.3.1->3lc) (1.17.0)
# Requirement already satisfied: fire in c:\project\notebook-examples\.venv\lib\site-packages (from randomname<1.0.0,>=0.2.1->3lc) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\project\notebook-examples\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->3lc) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\project\notebook-examples\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->3lc) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\project\notebook-examples\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->3lc) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from rich<14.0.0,>=13.4.2->3lc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\project\notebook-examples\.venv\lib\site-packages (from rich<14.0.0,>=13.4.2->3lc) (2.19.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\project\notebook-examples\.venv\lib\site-packages (from ruamel-yaml<1.0.0,>=0.17.32->3lc) (0.2.12)
# Requirement already satisfied: colorama in c:\project\notebook-examples\.venv\lib\site-packages (from tqdm<5.0.0,>=4.65.0->3lc) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\project\notebook-examples\.venv\lib\site-packages (from anyio>=3->litestar<2.16.0,>=2.15.0->3lc) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\project\notebook-examples\.venv\lib\site-packages (from cryptography>=44.0.1->3lc) (2.0.0)
# Requirement already satisfied: pycparser in c:\project\notebook-examples\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.1->3lc) (2.22)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in c:\project\notebook-examples\.venv\lib\site-packages (from deepdiff>=8.6.1->3lc) (5.5.0)
# Requirement already satisfied: httpcore==1.* in c:\project\notebook-examples\.venv\lib\site-packages (from httpx>=0.22->litestar<2.16.0,>=2.15.0->3lc) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\project\notebook-examples\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.22->litestar<2.16.0,>=2.15.0->3lc) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\project\notebook-examples\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.4.2->3lc) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\project\notebook-examples\.venv\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<1.0.0,>=0.52.1->3lc) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\project\notebook-examples\.venv\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<1.0.0,>=0.52.1->3lc) (0.4.2)
# Requirement already satisfied: uc-micro-py in c:\project\notebook-examples\.venv\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual<1.0.0,>=0.52.1->3lc) (1.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\project\notebook-examples\.venv\lib\site-packages (from pandas>=1.4.2->3lc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\project\notebook-examples\.venv\lib\site-packages (from pandas>=1.4.2->3lc) (2025.2)
# Requirement already satisfied: faker>=5.0.0 in c:\project\notebook-examples\.venv\lib\site-packages (from polyfactory>=2.6.3->litestar<2.16.0,>=2.15.0->3lc) (37.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\project\notebook-examples\.venv\lib\site-packages (from pydantic>=2->3lc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\project\notebook-examples\.venv\lib\site-packages (from pydantic>=2->3lc) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\project\notebook-examples\.venv\lib\site-packages (from pydantic>=2->3lc) (0.4.0)
# Requirement already satisfied: networkx in c:\project\notebook-examples\.venv\lib\site-packages (from torch>=1.8.0->3lc) (3.4.2)
# Requirement already satisfied: jinja2 in c:\project\notebook-examples\.venv\lib\site-packages (from torch>=1.8.0->3lc) (3.1.6)
# Requirement already satisfied: setuptools in c:\project\notebook-examples\.venv\lib\site-packages (from torch>=1.8.0->3lc) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\project\notebook-examples\.venv\lib\site-packages (from torch>=1.8.0->3lc) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\project\notebook-examples\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->3lc) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\project\notebook-examples\.venv\lib\site-packages (from jinja2->torch>=1.8.0->3lc) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pycocotools in c:\project\notebook-examples\.venv\lib\site-packages (2.0.10)
# Requirement already satisfied: numpy in c:\project\notebook-examples\.venv\lib\site-packages (from pycocotools) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
import json
from pathlib import Path

import numpy as np
import tlc
from pycocotools import mask as mask_utils

# %% [markdown]
# ## Get images and masks

# %%
coco128_path = Path(DATA_PATH) / "coco128"

# Open COCO128 annotations.json file and load the annotations
with open(coco128_path / "annotations.json") as f:
    annotations = json.load(f)

# Get the images, segmentations and classes from the data file
images = annotations["images"]
instances = annotations["annotations"]
classes = [category["name"] for category in annotations["categories"]]

# %% [markdown]
# We want to create a list of rows with the following structure:
#
# ```
# {
#     "image": str,
#     "segmentation: {
#         "image_width": int,
#         "image_height": int,
#         "instance_properties": {
#             "label": list[int],
#         },
#         "masks": np.ndarray
#     }
# }
# ```
#
# Where `image` is a path to the image file, and `segmentation` is a dict of the format expected by 3LC for polygon-based instance segmentation. Its fields are:
#
# - `image_width`: The width of the image
# - `image_height`: The height of the image
# - `instance_properties`: A dict of properties for each instance in the segmentation. The keys are the names of the properties, and the values are a list containing the value of that property for each instance in the image. Examples of instance properties include `label` and `confidence`.
# - `masks`: A numpy array of shape `(width, height, num_instances)` and dtype `uint8`, where each slice along the third dimension is a binary mask for one of the instances in the image. This specific format (order of dimensions and dtype) was chosen to match the format used by pycocotools, which is used for 3LCs handling of all instance segmentation data.
#
# We will now create a list of rows with the above structure.

# %%
# Create a list of rows, holding information about each image
# The instance properties are initially empty, and will be populated later
rows = [
    {
        "image": (coco128_path / "images" / image["file_name"]).absolute().as_posix(),
        "segmentation": {
            "image_width": image["width"],
            "image_height": image["height"],
            "instance_properties": {
                "label": [],
            },
            "masks": np.empty((image["width"], image["height"], 0), dtype=np.uint8),
        },
    }
    for image in images
]

# %%
# Create a mapping from image index to list of polygons
polygons = {i: [] for i in range(len(images))}

for instance in instances:
    # Get the row index for the instance
    row_id = instance["image_id"]

    # Get the label and polygon for the instance
    label = instance["category_id"]

    if isinstance(instance["segmentation"], list):
        polygon = instance["segmentation"][0]
    else:
        continue

    # Add the label to the row
    rows[row_id]["segmentation"]["instance_properties"]["label"].append(label)

    # Add the polygon to the list of polygons for the image
    polygons[row_id].append(polygon)

# %% [markdown]
# ### Convert the polygons to masks
#
# Since the instance segmentation data in COCO128 is represented as polygons, we need to convert the polygons to masks for the purposes of this example. If you are creating a Table from your own instance segmentation mask data, the only thing you need to ensure is that the format of the `masks` field matches the format expected by 3LC.
#
# Here, we use pycocotools to convert the polygons to masks.

# %%
# Iterate over all the images and convert the polygons to masks
for row_id, instance_polygons in polygons.items():
    # If there are no polygons for this image, create an empty mask
    if len(instance_polygons) == 0:
        rows[row_id]["segmentation"]["masks"] = np.empty(
            (images[row_id]["width"], images[row_id]["height"], 0), dtype=np.uint8
        )
        continue

    # Convert the polygons to a mask
    rles = mask_utils.frPyObjects(instance_polygons, images[row_id]["height"], images[row_id]["width"])
    masks = mask_utils.decode(rles)
    rows[row_id]["segmentation"]["masks"] = masks

# %% [markdown]
# ## Create a table from the rows
#
# We will now use a `TableWriter` to write the rows to a `Table`.

# %%
# Define the column schemas of our Table
column_schemas = {
    "image": tlc.ImageUrlSchema(),
    "segmentation": tlc.SegmentationSchema(
        label_value_map={i: tlc.MapElement(c) for i, c in enumerate(classes)},
        sample_type=tlc.InstanceSegmentationMasks.sample_type,
    ),
}

# %%
# Create a TableWriter
table_writer = tlc.TableWriter(
    table_name="initial",
    dataset_name=DATASET_NAME,
    project_name=PROJECT_NAME,
    column_schemas=column_schemas,
    if_exists="rename",
)

# %%
# Write the rows to the Table
for row in rows:
    table_writer.add_row(row)

# Once we are done, call `finalize()` to create the Table
table = table_writer.finalize()

# %% [markdown]
# The table will now be visible in the 3LC Dashboard and can be used in any of your scripts or notebooks.
